# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./20240813/history.csv")
data.head()
# Out:
#    timestep       reward  actor loss  critic loss
# 0       200 -1464.213837    2.477201    45.844018
# 1       400 -1667.652141    8.727048    10.346612
# 2       600 -1830.802806   13.800709     5.358488
# 3       800 -1475.988156   19.240851     1.523656
# 4      1000 -1667.853088   25.121420     1.066808

# %%
sns.set_theme(style = "darkgrid")

# %%
ax = sns.lineplot(x = "timestep", y = "reward", data = data, err_style = "band", alpha = 0.8)
plt.show()

# %%
ax = sns.lineplot(x = "timestep", y = "actor loss", data = data, err_style = "band", alpha = 0.8)
plt.show()

# %%
ax = sns.lineplot(x = "timestep", y = "critic loss", data = data, err_style = "band", alpha = 0.8)
plt.show()
